# %%
import cv2
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime

# %%
file_path = "../dataset/sequences/00/image_0/"
left_images = os.listdir(file_path)

# %%
left_images[:5]
# Out:
# ['000000.png', '000001.png', '000002.png', '000003.png', '000004.png']

# %%
plt.imshow(cv2.imread(file_path+left_images[0], 0))

# %%
image = cv2.imread(file_path+left_images[0], 0)
image.shape
# Out:
# (376, 1241)

# %%
calib = pd.read_csv('../dataset/sequences/00/calib.txt', delimiter=' ', header=None, index_col = 0)
print(calib)
Tr = np.array(calib.iloc[4]).reshape((3,4))
print(Tr)
# Out:
#              1         2           3           4         5           6   \
# 0
# P0:  718.856000  0.000000  607.192800    0.000000  0.000000  718.856000
# P1:  718.856000  0.000000  607.192800 -386.144800  0.000000  718.856000
# P2:  718.856000  0.000000  607.192800   45.382250  0.000000  718.856000
# P3:  718.856000  0.000000  607.192800 -337.287700  0.000000  718.856000
# Tr:    0.000428 -0.999967   -0.008084   -0.011985 -0.007211    0.008081
#
#              7         8         9         10        11        12
# 0
# P0:  185.215700  0.000000  0.000000  0.000000  1.000000  0.000000
# P1:  185.215700  0.000000  0.000000  0.000000  1.000000  0.000000
# P2:  185.215700 -0.113089  0.000000  0.000000  1.000000  0.003780
# P3:  185.215700  2.369057  0.000000  0.000000  1.000000  0.004915
# Tr:   -0.999941 -0.054040  0.999974  0.000486 -0.007207 -0.292197
# [[ 4.27680239e-04 -9.99967248e-01 -8.08449168e-03 -1.19845993e-02]
#  [-7.21062651e-03  8.08119847e-03 -9.99941316e-01 -5.40398473e-02]
#  [ 9.99973865e-01  4.85948581e-04 -7.20693369e-03 -2.92196865e-01]]

# %%
class Dataset_Handler():
    def __init__(self, sequence, lidar=True, low_memory=True):
        self.lidar = lidar
        self.low_memory = low_memory
        self.seq_dir = "../dataset/sequences/{}/".format(sequence)
        self.poses_dir = "../dataset/poses/{}.txt".format(sequence)
        
        #poses = pd.read_csv(self.poses_dir, delimiter= ' ', header=None)
        
        self.left_image_files = os.listdir(self.seq_dir+'image_0')
        self.right_image_files = os.listdir(self.seq_dir+'image_1')
        
        #self.left_image_files = os.listdir(self.seq_dir+'image_0')
        
        self.num_frames = len(self.left_image_files)
        #self.lidar_path = self.seq_dir + 'velodyne/'
        
        poses = pd.read_csv(self.poses_dir, delimiter=' ', header=None)
        self.gt = np.zeros((self.num_frames, 3, 4))
        
        for i in range(len(poses)):
            self.gt[i] = np.array(poses.iloc[i]).reshape(3,4)
            
        calib = pd.read_csv(self.seq_dir+'calib.txt', delimiter=' ', header=None, index_col = 0)
        self.P0 = np.array(calib.loc['P0:']).reshape((3,4))
        self.P1 = np.array(calib.loc['P1:']).reshape((3,4))
        self.P2 = np.array(calib.loc['P2:']).reshape((3,4))
        self.P3 = np.array(calib.loc['P3:']).reshape((3,4))
        self.Tr = np.array(calib.loc['Tr:']).reshape((3,4))
        
        if low_memory:
            self.reset_frames()
            self.first_image_left = cv2.imread(self.seq_dir+'image_0/'+ self.left_image_files[0], 0)
            self.first_image_right = cv2.imread(self.seq_dir+'image_1/'+ self.right_image_files[0], 0)
            self.second_image_left = cv2.imread(self.seq_dir+'image_0/'+ self.left_image_files[1], 0)
            #self.first_pointcloud = np.fromfile(self.lidar+velodyne_files[0])
            self.imheight = self.first_image_left.shape[0]
            self.imwidth = self.first_image_left.shape[1]
            
        else:
            self.images_left = []
            self.images_right = []
            for i, name_left in enumerate(self.left_image_files):
                name_right = self.right_image_files[i]
                self.images_left.append(cv2.imread(self.seq_dir+'image_0/'+name_left,0))
                self.images_right.append(cv2.imread(self.seq_dir+'image_1/'+name_right,0))
                self.imheight = self.images_left[0].shape[0]
                self.imwidth = self.images_right[0].shape[1]
            
    def reset_frames(self):
        self.images_left = (cv2.imread(self.seq_dir+'image_0/'+name_left, 0) for name_left in self.left_image_files)
        self.images_right = (cv2.imread(self.seq_dir+'image_0/'+name_right, 0) for name_left in self.right_image_files)
        #self.pointclouds = (np.fromfile(self.lidar+velodyne_file, dtype=np.float32).reshape((-1,4)) for velodyne_file in self.velodyne_files)

# %%
seq_dir = "../dataset/sequences/00/"
calib = pd.read_csv(seq_dir+'calib.txt', delimiter=' ', header=None, index_col=0)
P0 = np.array(calib.loc['P0:']).reshape((3,4))
P1 = np.array(calib.loc['P1:']).reshape((3,4))
P2 = np.array(calib.loc['P2:']).reshape((3,4))
P3 = np.array(calib.loc['P3:']).reshape((3,4))
Tr = np.array(calib.loc['Tr:']).reshape((3,4))

# %%
# handler = Dataset_Handler('00', low_memory=False)

# %%
handler2= Dataset_Handler('00')

# %%
handler2.first_image_left.shape
# Out:
# (376, 1241)

# %%
# %matplotlib inline

# %%
# plt.figure(figsize=(11,7))
# plt.imshow(handler.images_left[0])

# %%
plt.figure(figsize=(11,7))
plt.imshow(next(handler2.images_left))

# %%
def compute_left_disparity_map(image_left, image_right, matcher='bm', rgb=False, verbose=False):
    sad_window = 6
    num_disparities = sad_window * 16
    matcher_name = matcher
    block_size = 11
    
    if matcher_name =='bm':
        matcher = cv2.StereoBM_create(numDisparities=num_disparities, blockSize=block_size)
        
    elif matcher_name == 'sgbm':
        matcher = cv2.StereoSGBM_create(numDisparities=num_disparities, minDisparity =0, blockSize=block_size, 
                                       P1 = 8 * 3 * sad_window ** 2, P2 = 32 * 3 * sad_window ** 2,
                                       mode = cv2.STEREO_SGBM_MODE_SGBM_3WAY)
        
    if rgb:
        image_left = cv2.cvtColor(image_left, cv2.COLOR_BGR2GRAY)
        image_right = cv2.cvtColor(image_right, cv2.COLOR_BGR2GRAY)
        
    start = datetime.datetime.now()
    disp_left = matcher.compute(image_left, image_right).astype(np.float32)/16
    print("Data type of disparity map: ", type(disp_left))
    end = datetime.datetime.now()
    
    if verbose:
        print(f'Time to compute disparity map using Stereo{matcher_name.upper()}', end-start)
        
    
    return disp_left

# %%
disp = compute_left_disparity_map(handler2.first_image_left, handler2.first_image_right, matcher='bm', verbose=True)
plt.figure(figsize=(11,7))
plt.imshow(disp)
# Out:
# Data type of disparity map:  <class 'numpy.ndarray'>
# Time to compute disparity map using StereoBM 0:00:00.031742

# %%
disp = compute_left_disparity_map(handler2.first_image_left, handler2.first_image_right, matcher='sgbm', verbose=True)
plt.figure(figsize=(11,7))
plt.imshow(disp)
# Out:
# Data type of disparity map:  <class 'numpy.ndarray'>
# Time to compute disparity map using StereoSGBM 0:00:00.087203

# %%
image_left = handler2.first_image_left
image_right = handler2.first_image_right
concatenated_image = np.hstack((image_left, image_right))
plt.figure(figsize=(11,11))
plt.imshow(concatenated_image, cmap='gray')  # Use the 'gray' colormap if the images are grayscale
plt.title('Juxtaposed Images')
plt.axis('off')  # Optionally turn off the axis
plt.show()

# %%
print(disp.shape)
# Out:
# (376, 1241)

# %%
k,r,t,_,_,_,_ = cv2.decomposeProjectionMatrix(handler.P1)
print(k)
print(r)
print(t)
# Out:
# [[718.856    0.     607.1928]
#  [  0.     718.856  185.2157]
#  [  0.       0.       1.    ]]
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# [[ 4.73214622e-001]
#  [ 1.23904412e-017]
#  [-4.94065646e-324]
#  [ 8.80947173e-001]]

# %%
def decompose_projection_matrix(p):
    k,r,t,_,_,_,_ = cv2.decomposeProjectionMatrix(p)
    t = (t/t[3])[:3]
    return k,r,t

# %%
def calc_depth_map(disp_left, k_left, t_left, t_right, rectified=True):
    if rectified:
        b = t_right[0] - t_left[0]
    else:
        b = t_left[0] - t_right[0]
        
    f = k_left[0][0]
    
    disp_left[disp_left==0] = 0.1
    disp_left[disp_left==-1] = 0.1
    
    depth_map = np.ones(disp_left.shape)
    depth_map = f * b / disp_left
    
    return depth_map

# %%
k_left, r_left, t_left = decompose_projection_matrix(handler.P0)
k_right, r_right, t_right = decompose_projection_matrix(handler.P1)

# %%
depth = calc_depth_map(disp, k_left, t_left, t_right)
plt.figure(figsize=(11,7))
plt.imshow(depth)

# %%
depth[0,0]
# Out:
# 3861.447942459941

# %%
pip install jupyterthemes
# Out:
# Collecting jupyterthemesNote: you may need to restart the kernel to use updated packages.
#
#   Downloading jupyterthemes-0.20.0-py2.py3-none-any.whl (7.0 MB)
#      ---------------------------------------- 7.0/7.0 MB 22.4 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=1.4.3 in c:\users\arun2\anaconda3\lib\site-packages (from jupyterthemes) (3.7.0)
# Requirement already satisfied: jupyter-core in c:\users\arun2\anaconda3\lib\site-packages (from jupyterthemes) (5.2.0)
# Collecting lesscpy>=0.11.2
#   Downloading lesscpy-0.15.1-py2.py3-none-any.whl (46 kB)
#      ---------------------------------------- 46.7/46.7 kB ? eta 0:00:00
# Requirement already satisfied: notebook>=5.6.0 in c:\users\arun2\anaconda3\lib\site-packages (from jupyterthemes) (6.5.2)
# Requirement already satisfied: ipython>=5.4.1 in c:\users\arun2\anaconda3\lib\site-packages (from jupyterthemes) (8.10.0)
# Requirement already satisfied: pickleshare in c:\users\arun2\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.7.5)
# Requirement already satisfied: decorator in c:\users\arun2\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (5.1.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in c:\users\arun2\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (3.0.36)
# Requirement already satisfied: colorama in c:\users\arun2\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.4.6)
# Requirement already satisfied: traitlets>=5 in c:\users\arun2\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (5.7.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\arun2\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\arun2\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.1.6)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\arun2\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (2.11.2)
# Requirement already satisfied: stack-data in c:\users\arun2\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.2.0)
# Requirement already satisfied: backcall in c:\users\arun2\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.2.0)
# Requirement already satisfied: ply in c:\users\arun2\anaconda3\lib\site-packages (from lesscpy>=0.11.2->jupyterthemes) (3.11)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\arun2\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (9.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\arun2\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (0.11.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\arun2\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.23.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\arun2\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (4.25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\arun2\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\arun2\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\arun2\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (22.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\arun2\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\arun2\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.4.4)
# Requirement already satisfied: jinja2 in c:\users\arun2\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (3.1.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\arun2\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.17.1)
# Requirement already satisfied: ipython-genutils in c:\users\arun2\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.2.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\arun2\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (7.3.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\arun2\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (1.8.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\arun2\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (6.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\arun2\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.5.2)
# Requirement already satisfied: argon2-cffi in c:\users\arun2\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (21.3.0)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\arun2\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (1.5.6)
# Requirement already satisfied: ipykernel in c:\users\arun2\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (6.19.2)
# Requirement already satisfied: nbconvert>=5 in c:\users\arun2\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (6.5.4)
# Requirement already satisfied: prometheus-client in c:\users\arun2\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.14.1)
# Requirement already satisfied: nbformat in c:\users\arun2\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (5.7.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\arun2\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (23.2.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\arun2\anaconda3\lib\site-packages (from jupyter-core->jupyterthemes) (2.5.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\arun2\anaconda3\lib\site-packages (from jupyter-core->jupyterthemes) (305.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\arun2\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.4.1->jupyterthemes) (0.8.3)
# Requirement already satisfied: entrypoints in c:\users\arun2\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook>=5.6.0->jupyterthemes) (0.4)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\arun2\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\arun2\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (0.2.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\arun2\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.5.13)
# Requirement already satisfied: jupyterlab-pygments in c:\users\arun2\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.1.2)
# Requirement already satisfied: bleach in c:\users\arun2\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (4.1.0)
# Requirement already satisfied: tinycss2 in c:\users\arun2\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (1.2.1)
# Requirement already satisfied: defusedxml in c:\users\arun2\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.7.1)
# Requirement already satisfied: lxml in c:\users\arun2\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (4.9.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\arun2\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (4.11.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\arun2\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (2.1.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\arun2\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (1.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\arun2\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.8.4)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\arun2\anaconda3\lib\site-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (4.17.3)
# Requirement already satisfied: fastjsonschema in c:\users\arun2\anaconda3\lib\site-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\arun2\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=5.4.1->jupyterthemes) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\arun2\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=1.4.3->jupyterthemes) (1.16.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\arun2\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=5.6.0->jupyterthemes) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\arun2\anaconda3\lib\site-packages (from argon2-cffi->notebook>=5.6.0->jupyterthemes) (21.2.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\arun2\anaconda3\lib\site-packages (from ipykernel->notebook>=5.6.0->jupyterthemes) (0.1.2)
# Requirement already satisfied: psutil in c:\users\arun2\anaconda3\lib\site-packages (from ipykernel->notebook>=5.6.0->jupyterthemes) (5.9.0)
# Requirement already satisfied: debugpy>=1.0 in c:\users\arun2\anaconda3\lib\site-packages (from ipykernel->notebook>=5.6.0->jupyterthemes) (1.5.1)
# Requirement already satisfied: executing in c:\users\arun2\anaconda3\lib\site-packages (from stack-data->ipython>=5.4.1->jupyterthemes) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\arun2\anaconda3\lib\site-packages (from stack-data->ipython>=5.4.1->jupyterthemes) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\arun2\anaconda3\lib\site-packages (from stack-data->ipython>=5.4.1->jupyterthemes) (2.0.5)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\arun2\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\arun2\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (22.1.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\arun2\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (3.5.0)
# Requirement already satisfied: websocket-client in c:\users\arun2\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\arun2\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=5.6.0->jupyterthemes) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\arun2\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=5.6.0->jupyterthemes) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\arun2\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.5.1)
# Requirement already satisfied: idna>=2.8 in c:\users\arun2\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\arun2\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\arun2\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=5.6.0->jupyterthemes) (2.21)
# Installing collected packages: lesscpy, jupyterthemes
# Successfully installed jupyterthemes-0.20.0 lesscpy-0.15.1

# %%
from jupyterthemes import jtplot
jtplot.style()

# %%
plt.hist(depth.flatten())
# Out:
# (array([405883.,    646.,      0.,      0.,      0.,      0.,      0.,
#              0.,      0.,  60087.]),
#  array([   4.06468211,  389.80300814,  775.54133418, 1161.27966021,
#         1547.01798625, 1932.75631228, 2318.49463832, 2704.23296435,
#         3089.97129039, 3475.70961642, 3861.44794246]),
#  <BarContainer object of 10 artists>)

# %%
depth[depth<depth.max()].flatten().max()
# Out:
# 686.4796444444443

# %%
for i, pixel in enumerate(depth[0]):
    if pixel < depth.max():
        print(f"First non-max value at {i}")
        break
# Out:
# First non-max value at 96

# %%
mask = np.zeros(depth.shape, dtype=np.uint8)
ymax = depth.shape[0]
xmax = depth.shape[1]
cv2.rectangle(mask, (96,0), (xmax, ymax), 255, thickness=-1)
plt.imshow(mask)
